# %% [markdown]
# # 各級學校縣市別學生人數統計資料(106學年度~110學年度)
#     資料來源：https://data.gov.tw/dataset/40121
#     因需要繪圖，先 pip install matplotlib

# %% [markdown]
# ### 1. 匯入106edu.csv的資料，並列出表格

# %%
import pandas as pd
data = pd.read_csv('106edu.csv')
data.head()
# Out:
#    學年度  縣市別    幼兒園      國小      國中  高級中等學校-普通科  高級中等學校-專業(職業)群科  高級中等學校-綜合高中  \
# 0  106  新北市  81348  192321  100608       40999            37328         5581
# 1  106  臺北市  52253  115679   66746       58742            35058         4072
# 2  106  桃園市  51322  122590   67375       29822            35420         3032
# 3  106  臺中市  77619  150412   85244       37962            50784         2020
# 4  106  臺南市  46663   87329   50556       25817            22075         4418
#
#    高級中等學校-實用技能學程  高級中等學校-進修部(學校)  大專校院(全部計入校本部)  大專校院(跨縣市教學計入所在地縣市)  宗教研修學院  \
# 0            917            5336         151475              145054     116
# 1            377            5448         263668              241829      81
# 2           4770            5965         102983              114101       0
# 3           3836            6211         188641              188114       0
# 4           4007            2540         124447              126610       0
#
#    國民補習及大專進修學校及空大  特殊教育學校
# 0           16615     385
# 1            8120     779
# 2            2633     450
# 3            9450     897
# 4            1397     482

# %% [markdown]
# ### 2. 列出106學年幼兒園、國小、國中、高級中等學校-普通科、高級中等學校-專業(職業)群科、大專校院(全部計入校本部)的學生人數分布折線圖

# %%
import matplotlib

# 找出套件安裝位置
print(matplotlib.__file__)
# Out:
# C:\Users\Peggy\anaconda3\lib\site-packages\matplotlib\__init__.py

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('106edu.csv')

# 篩選我們要的資料
Area = df["縣市別"]
Kindergarten = df["幼兒園"]
Primary = df["國小"]
Junior = df["國中"]
Senior = df["高級中等學校-普通科"]
Vocational = df["高級中等學校-專業(職業)群科"]
University = df["大專校院(全部計入校本部)"]

# 將字體換成體
plt.rcParams['font.sans-serif'] = ['Iansui']
# 修復負號顯示問題
plt.rcParams['axes.unicode_minus']=False

# 繪圖
plt.plot(Area, Kindergarten)
plt.plot(Area, Primary)
plt.plot(Area, Junior)
plt.plot(Area, Senior)
plt.plot(Area, Vocational)
plt.plot(Area, University)

plt.xlabel("Area")    # x軸標籤
plt.ylabel("population")    # y軸標籤
plt.legend(["Kindergarten", "Primary", "Junior", "Senior", "Vocational", "University"], loc="upper right")    # 圖示，共有左下、左上、右下、右上四個方位
plt.title("Line chart of the number of students in schools for the academic year 106")    # 主標題
plt.grid(True)    # 是否有網格?

# 設定 x 軸標籤

plt.xticks(range(len(Area)), ["NTPC", "TPE", "TYN", "TXG", "TNN", "KHH", "ILA(County)", "HSZ(County)", "ZMI(County)", "CHW(County)", "NTC(County)", "YUN(County)", "CYI(County)", "PIF(County)", "TTT(County)", "HUN(County)", "PEH(County)", "KEL", "HSZ", "CYI", "KNH(County)", "LNN (County)"], rotation=85, fontsize=8)

# 顯示圖片
plt.show()

# %% [markdown]
# ### 3. 各縣市哪一個學制的人數最多?

# %%
import pandas as pd

# 讀取CSV檔
df = pd.read_csv('106edu.csv')

# 取出需要處理的部分表格資料
data = pd.concat([df.iloc[0, 2:7], df.iloc[9, 2:3]]).astype(float)

# 找出最大值所在的位置
max_index = data.argmax()

# 將最大值所在的位置轉換為對應的文字
if max_index == 0:
    inf = '幼兒園'
elif max_index == 1:
    inf = '國小'
elif max_index == 2:
    inf = '國中'
elif max_index == 3:
    inf = '高級中等學校-普通科'
elif max_index == 4:
    inf = '高級中等學校-專業群科'
elif max_index == 5:
    inf = '大專校院(全部計入校本部)'
else:
    inf = 'Unknown'

# 輸出結果
print('該縣市中最多學生數的學制在', inf)
# Out:
# 該縣市中最多學生數的學制在 國小

# %%
import pandas as pd

# 讀取CSV檔
df = pd.read_csv('106edu.csv')

# 取出所有不重複的縣市名稱
counties = df['縣市別'].unique()

for county in counties:
    # 取出這個縣市的資料
    county_data = df[df['縣市別'] == county]
    
    # 取出需要處理的部分表格資料
    data = county_data.iloc[:, [2, 3, 4, 5, 6, 10]].astype(float)

    # 找出最大值所在的位置
    max_index = data.argmax()

    # 將最大值所在的位置轉換為對應的文字
    if max_index == 0:
        inf = '幼兒園'
    elif max_index == 1:
        inf = '國小'
    elif max_index == 2:
        inf = '國中'
    elif max_index == 3:
        inf = '高級中等學校-普通科'
    elif max_index == 4:
        inf = '高級中等學校-專業群科'
    elif max_index == 5:
        inf = '大專校院(全部計入校本部)'
    else:
        inf = 'Unknown'

    # 輸出結果
    print(county, '中最多學生數的學制在', inf, '，人數為', data[max_index], '人')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12956\1999645343.py in <module>
#      15
#      16     # 找出最大值所在的位置
# ---> 17     max_index = data.argmax()
#      18
#      19     # 將最大值所在的位置轉換為對應的文字
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'argmax'

# %%
import pandas as pd

# 讀取CSV檔
df = pd.read_csv('106edu.csv')

# 取出所有不重複的縣市名稱
counties = df['縣市別'].unique()

for county in counties:
    # 取出這個縣市的資料
    county_data = df[df['縣市別'] == county]
    
    # 取出需要處理的部分表格資料
    data = county_data.iloc[:, [2, 3, 4, 5, 6, 10]].astype(float)

    # 找出最大值所在的位置
    max_index = data.idxmax().index[0]

    # 將最大值所在的位置轉換為對應的文字
    if max_index == 2:
        inf = '幼兒園'
    elif max_index == 3:
        inf = '國小'
    elif max_index == 4:
        inf = '國中'
    elif max_index == 5:
        inf = '高級中等學校-普通科'
    elif max_index == 6:
        inf = '高級中等學校-專業群科'
    elif max_index == 10:
        inf = '大專校院(全部計入校本部)'
    else:
        inf = 'Unknown'

    # 輸出結果
    print(county, '中最多學生數的學制在', inf, '，人數為', data[max_index], '人')
# Out:
# 新北市 中最多學生數的學制在 Unknown ，人數為 0    81348.0
# Name: 幼兒園, dtype: float64 人
# 臺北市 中最多學生數的學制在 Unknown ，人數為 1    52253.0
# Name: 幼兒園, dtype: float64 人
# 桃園市 中最多學生數的學制在 Unknown ，人數為 2    51322.0
# Name: 幼兒園, dtype: float64 人
# 臺中市 中最多學生數的學制在 Unknown ，人數為 3    77619.0
# Name: 幼兒園, dtype: float64 人
# 臺南市 中最多學生數的學制在 Unknown ，人數為 4    46663.0
# Name: 幼兒園, dtype: float64 人
# 高雄市 中最多學生數的學制在 Unknown ，人數為 5    56968.0
# Name: 幼兒園, dtype: float64 人
# 宜蘭縣 中最多學生數的學制在 Unknown ，人數為 6    10639.0
# Name: 幼兒園, dtype: float64 人
# 新竹縣 中最多學生數的學制在 Unknown ，人數為 7    16035.0
# Name: 幼兒園, dtype: float64 人
# 苗栗縣 中最多學生數的學制在 Unknown ，人數為 8    11727.0
# Name: 幼兒園, dtype: float64 人
# 彰化縣 中最多學生數的學制在 Unknown ，人數為 9    26724.0
# Name: 幼兒園, dtype: float64 人
# 南投縣 中最多學生數的學制在 Unknown ，人數為 10    10345.0
# Name: 幼兒園, dtype: float64 人
# 雲林縣 中最多學生數的學制在 Unknown ，人數為 11    13617.0
# Name: 幼兒園, dtype: float64 人
# 嘉義縣 中最多學生數的學制在 Unknown ，人數為 12    8649.0
# Name: 幼兒園, dtype: float64 人
# 屏東縣 中最多學生數的學制在 Unknown ，人數為 13    15592.0
# Name: 幼兒園, dtype: float64 人
# 臺東縣 中最多學生數的學制在 Unknown ，人數為 14    4643.0
# Name: 幼兒園, dtype: float64 人
# 花蓮縣 中最多學生數的學制在 Unknown ，人數為 15    7017.0
# Name: 幼兒園, dtype: float64 人
# 澎湖縣 中最多學生數的學制在 Unknown ，人數為 16    1766.0
# Name: 幼兒園, dtype: float64 人
# 基隆市 中最多學生數的學制在 Unknown ，人數為 17    6909.0
# Name: 幼兒園, dtype: float64 人
# 新竹市 中最多學生數的學制在 Unknown ，人數為 18    13284.0
# Name: 幼兒園, dtype: float64 人
# 嘉義市 中最多學生數的學制在 Unknown ，人數為 19    6466.0
# Name: 幼兒園, dtype: float64 人
# 金門縣 中最多學生數的學制在 Unknown ，人數為 20    2026.0
# Name: 幼兒園, dtype: float64 人
# 連江縣 中最多學生數的學制在 Unknown ，人數為 21    292.0
# Name: 幼兒園, dtype: float64 人

# %%
df107 = pd.read_csv('107edu.csv')
df108 = pd.read_csv('108edu.csv')
df109 = pd.read_csv('109edu.csv')
df110 = pd.read_csv('110edu.csv')
