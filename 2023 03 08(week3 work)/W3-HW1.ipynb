# %% [markdown]
# # 國小視力不良統計資料(100學年度~109學年度)
#     資料來源：https://www.stat.gov.tw/Statistics.aspx?n=2978&CaN=295
#     因使用ods檔，需先 pip install odfpy

# %% [markdown]
# ## 1.匯入資料

# %%
import pandas as pd

pd.read_excel('~/Desktop/github/LAT-Repo/2023 03 08(week3 work)/W3 homework.ods', engine='odf')
# Out:
#      項目         全國 Unnamed: 2 Unnamed: 3         公立 Unnamed: 5 Unnamed: 6  \
# 0   學年度         平均          男          女         平均          男          女
# 1   100      50.01      48.89      51.24      49.95      48.84      51.17
# 2   101  49.361388  48.405038  50.409395  49.291184  48.333063  50.338987
# 3   102   48.10794  47.331407  48.959603  48.053444  47.275555   48.90522
# 4   103  47.052129  46.467743  47.693371  46.974962  46.396574  47.608638
# 5   104  46.121721  45.508135  46.793976  46.026275  45.411223   46.69939
# 6   105  45.855873  45.076418  46.707088  45.780815  45.005549  46.626942
# 7   106  45.478238   44.63659  46.396042   45.41818  44.569997  46.342784
# 8   107  44.788008  43.835774  45.821373  44.739549  43.789502  45.770716
# 9   108      44.33      43.39      45.35  44.340803  43.394221  45.365693
# 10  109  44.552649  43.604685  45.574055  44.512417  43.586382  45.511182
#
#            私立 Unnamed: 8 Unnamed: 9
# 0          平均          男          女
# 1       52.46      51.03      54.17
# 2   52.240871  51.240744  53.433057
# 3   50.189699   49.40248  51.108042
# 4    49.78803  48.924585  50.789241
# 5    49.30759  48.685195  50.015191
# 6   48.236085  47.302684  49.275191
# 7   47.286357  46.630966   48.00871
# 8   46.182861  45.170921  47.275658
# 9   44.627466   43.47951  45.850548
# 10  45.653445  44.112327  47.269642

# %% [markdown]
# ## 2.選擇資料中的國小視力不良率-縣市表

# %%
pd.read_excel("W3 homework.ods", sheet_name="國小視力不良率-縣市")
# Out:
#    學年度        基隆市        臺北市        新北市     桃園縣(市)        新竹市        新竹縣  \
# 0  100  52.950000  52.390000  54.630000  49.540000  49.730000  46.720000
# 1  101  50.870000  51.560000  53.430000  49.460000  49.400000  46.170000
# 2  102  48.440000  50.420000  51.110000  48.930000  48.240000  46.370000
# 3  103  47.021158  49.437483  49.910578  49.204327  45.924749  45.231322
# 4  104  46.314511  47.921203  49.107343  39.926550  45.993894  44.789013
# 5  105  46.513452  47.049203  48.712291  39.165242  44.885512  44.847973
# 6  106  47.132436  46.024006  48.188869  38.449706  44.820095  44.500042
# 7  107  46.277603  44.546728  47.541135  46.124896  43.695943  43.820813
# 8  108  47.130000  43.580000  46.570000  47.460000  42.010000  44.540000
# 9  109  47.380586  43.907165  46.527595  46.060311  42.366400  44.997716
#
#          苗栗縣        臺中市        南投縣  ...        嘉義縣        臺南市        高雄市  \
# 0  43.900000  53.300000  42.230000  ...  41.470000  49.590000  51.160000
# 1  44.130000  52.510000  42.370000  ...  41.920000  49.490000  50.310000
# 2  42.920000  51.270000  40.970000  ...  40.930000  47.820000  48.420000
# 3  41.120166  49.552625  40.513202  ...  41.557204  46.444270  46.442814
# 4  41.837900  48.084614  40.055151  ...  40.811125  48.369704  45.735997
# 5  42.146146  48.171283  39.131156  ...  41.955684  48.271714  45.411810
# 6  42.277015  46.996310  39.411333  ...  41.571999  47.935234  44.803180
# 7  42.957899  47.541726  39.003693  ...  41.408843  44.033439  44.383320
# 8  43.720000  44.050000  37.750000  ...  39.850000  43.700000  38.930000
# 9  44.545058  47.755525  37.861363  ...  40.334615  43.980000  43.920588
#
#          屏東縣        宜蘭縣        花蓮縣        臺東縣        澎湖縣        金門縣        連江縣
# 0  38.840000  43.340000  36.360000  31.270000  41.590000  44.150000  45.510000
# 1  37.850000  43.440000  37.270000  31.030000  42.050000  44.810000  49.040000
# 2  36.900000  42.310000  37.750000  29.660000  42.420000  44.390000  44.010000
# 3  37.164614  40.684140  38.228262  29.127540  42.372479  41.600438  43.404255
# 4  36.713924  45.151867  37.784918  28.517655  42.272727  43.036250  39.909297
# 5  36.666934  44.973610  37.079361  27.678655  42.830441  39.534239  45.555556
# 6  37.474662  44.727484  36.573107  26.048799  42.308786  38.831996  40.421053
# 7  36.896001  38.365632  36.554317  25.216621  40.881590  35.382550  42.259414
# 8  36.310000  46.080000  36.850000  25.400000  40.560000  35.760000  41.880000
# 9  36.793006  39.674669  37.451123  26.253203  40.923707  36.702831  41.140530
#
# [10 rows x 23 columns]

# %% [markdown]
# #### 第一題
#     問：哪個縣市的哪年度學生視力不良率最高/最低？

# %% [markdown]
# 最高值為 54.63，所在的縣市為 新北市，所在的學年度為 100

# %%
import pyexcel_ods3

# 打开ODS文件
data = pyexcel_ods3.get_data("W3 homework.ods")

# 获取第一个工作表的数据
sheet_data = data['國小視力不良率-縣市']

# 读取第一行和第一列的数据
year = []
city = []
if len(sheet_data) > 0:
    row1 = sheet_data[0]
    year = row1[1:] if len(row1) > 1 else []
if len(sheet_data) > 1:
    col1 = sheet_data[1]
    city = [row[0] for row in sheet_data[1:] if len(row) > 0]

# 初始化最大值和最大值列表
max_value = None
max_rows = []
max_columns = []

# 遍历每一列并比较最大值
for i, column in enumerate(sheet_data):
    # 跳过第一列
    if i == 0:
        continue
    # 初始化当前列的数字值列表和行号列表
    values = []
    rows = []
    # 遍历当前列的单元格
    for j, value in enumerate(column):
        # 跳过第一行
        if j == 0:
            continue
        # 将每个值转换为数字类型
        try:
            value = float(value)
            values.append(value)
            rows.append(j)
        except ValueError:
            pass
    # 获取当前列的最大值
    if len(values) > 0:
        current_max = max(values)
        # 如果当前列的最大值大于前面的最大值，更新最大值和最大值列表
        if max_value is None or current_max > max_value:
            max_value = current_max
            max_columns = [i]
            max_rows = [rows[k] for k in range(len(values)) if values[k] == current_max]
        # 如果当前列的最大值等于前面的最大值，将列号和行号添加到最大值列表中
        elif current_max == max_value:
            max_columns.append(i)
            max_rows.extend([rows[k] for k in range(len(values)) if values[k] == current_max])

# 输出最大值所在的学年度和县市
if max_value is not None and len(max_rows) > 0 and len(max_columns) > 0:
    year_str = ", ".join([year[row-1] for row in max_rows if row > 0 and row <= len(year)])
    city_str = ", ".join([str(city[col-1]) for col in max_columns if col > 0 and col-1 < len(city)])
    print("最大值為 {}，所在的縣市為 {}，所在的學年度為 {}".format(max_value, year_str, city_str))
else:
    print("數據為空，無法獲取最大值所在的學年度和縣市。")
# Out:
# 最大值為 54.63，所在的縣市為 新北市，所在的學年度為 100

# %% [markdown]
# 最低值為 25.2166207168176，所在的縣市為 臺東縣，所在的學年度為 100

# %%
import pyexcel_ods3

# 打开ODS文件
data = pyexcel_ods3.get_data("W3 homework.ods")

# 获取第一个工作表的数据
sheet_data = data['國小視力不良率-縣市']

# 读取第一行和第一列的数据
year = []
city = []
if len(sheet_data) > 0:
    row1 = sheet_data[0]
    year = row1[1:] if len(row1) > 1 else []
if len(sheet_data) > 1:
    col1 = sheet_data[1]
    city = [row[0] for row in sheet_data[1:] if len(row) > 0]

# 初始化最小值和最小值列表
min_value = None
min_rows = []
min_columns = []

# 遍历每一列并比较最小值
for i, column in enumerate(sheet_data):
    # 跳过第一列
    if i == 0:
        continue
    # 初始化当前列的数字值列表和行号列表
    values = []
    rows = []
    # 遍历当前列的单元格
    for j, value in enumerate(column):
        # 跳过第一行
        if j == 0:
            continue
        # 将每个值转换为数字类型
        try:
            value = float(value)
            values.append(value)
            rows.append(j)
        except ValueError:
            pass
    # 获取当前列的最小值
    if len(values) > 0:
        current_min = min(values)
        # 如果当前列的最小值小于前面的最小值，更新最小值和最小值列表
        if min_value is None or current_min < min_value:
            min_value = current_min
            min_columns = [i]
            min_rows = [rows[k] for k in range(len(values)) if values[k] == current_min]
        # 如果当前列的最小值等于前面的最小值，将列号和行号添加到最小值列表中
        elif current_min == min_value:
            min_columns.append(i)
            min_rows.extend([rows[k] for k in range(len(values)) if values[k] == current_min])

# 输出最小值所在的学年度和县市
if min_value is not None and len(min_rows) > 0 and len(min_columns) > 0:
    year_str = ", ".join([str(year[row-1]) for row in min_rows if row > 0 and row <= len(year)])
    city_str = ", ".join([str(city[col-1]) for col in max_columns if col > 0 and col-1 < len(city)])
    print("最小值為 {}，所在的縣市為 {}，所在的學年度為 {}".format(min_value, year_str, city_str))
else:
    print("數據為空，無法獲取最小值所在的學年度和縣市。")
# Out:
# 最小值為 25.2166207168176，所在的縣市為 臺東縣，所在的學年度為 100

# %% [markdown]
# #### 第二題
#     問：各縣市的學生視力不良率是否呈現逐年攀升？

# %% [markdown]
# 計算各縣市成長率(資料只有匯出至雲林縣)

# %%
import ezodf

# 讀取 ods 檔案
doc = ezodf.opendoc('W3 homework.ods')

# 選擇要分析的工作表
sheet = doc.sheets['國小視力不良率-縣市']

# 讀取縣市名稱和學年度
cities = [cell.value for cell in sheet.row(0)[1:]]
years = [cell.value for cell in sheet.column(0)[1:]]

# 讀取不良率數據
data = []
for row in list(sheet.rows())[1:]:
    data_row = []
    for cell in row[1:]:
        if cell.value is not None:
            data_row.append(float(cell.value))
        else:
            data_row.append(None)
    data.append(data_row)

# 計算成長率
growth_rates = []
for i, city_data in enumerate(data):
    growth_rates.append([])
    for j in range(len(years) - 1):
        if city_data[j] is not None and city_data[j+1] is not None:
            growth_rate = (city_data[j+1] - city_data[j]) / city_data[j] * 100
            growth_rates[i].append(growth_rate)
        else:
            growth_rates[i].append(None)
    # 確保 growth_rates[i] 至少有 len(years) - 1 個元素
    while len(growth_rates[i]) < len(years) - 1:
        growth_rates[i].append(None)

# 列出結果
for i, city in enumerate(cities):
    print(city)
    if len(growth_rates[i]) < len(years) - 1:
        growth_rates[i] += [None] * (len(years) - 1 - len(growth_rates[i]))
    for j, year in enumerate(years):
        if j == 0:
            continue
        if growth_rates[i][j-1] is not None:
            print(f"{year}: {growth_rates[i][j-1]:.2f}%")
        else:
            print(f"{year}: N/A")
# Out:
# 基隆市
# 101.0: -1.06%
# 102.0: 4.28%
# 103.0: -9.32%
# 104.0: 0.38%
# 105.0: -6.05%
# 106.0: -6.04%
# 107.0: 21.41%
# 108.0: -20.77%
# 109.0: 24.70%
# None: -14.76%
# 臺北市
# 101.0: 1.36%
# 102.0: 3.63%
# 103.0: -7.43%
# 104.0: -0.12%
# 105.0: -6.54%
# 106.0: -4.42%
# 107.0: 18.99%
# 108.0: -19.31%
# 109.0: 21.86%
# None: -14.70%
# 新北市
# 101.0: 4.09%
# 102.0: 1.37%
# 103.0: -4.27%
# 104.0: -1.41%
# 105.0: -3.88%
# 106.0: -7.44%
# 107.0: 19.45%
# 108.0: -20.09%
# 109.0: 25.48%
# None: -15.85%
# 桃園縣(市)
# 101.0: 5.14%
# 102.0: 0.96%
# 103.0: -1.42%
# 104.0: -6.67%
# 105.0: -1.51%
# 106.0: -9.09%
# 107.0: 20.51%
# 108.0: -18.24%
# 109.0: 24.11%
# None: -15.99%
# 新竹市
# 101.0: 3.47%
# 102.0: 2.48%
# 103.0: -18.70%
# 104.0: 15.20%
# 105.0: -2.62%
# 106.0: -6.59%
# 107.0: 14.93%
# 108.0: -16.70%
# 109.0: 19.01%
# None: -9.90%
# 新竹縣
# 101.0: 1.15%
# 102.0: 3.53%
# 103.0: -19.60%
# 104.0: 14.61%
# 105.0: -0.08%
# 106.0: -6.02%
# 107.0: 14.30%
# 108.0: -18.77%
# 109.0: 21.37%
# None: -10.55%
# 苗栗縣
# 101.0: -2.35%
# 102.0: 4.70%
# 103.0: -20.21%
# 104.0: 16.57%
# 105.0: -0.71%
# 106.0: -5.00%
# 107.0: 11.16%
# 108.0: -16.14%
# 109.0: 21.07%
# None: -8.54%
# 臺中市
# 101.0: -3.74%
# 102.0: 6.72%
# 103.0: -2.98%
# 104.0: -5.27%
# 105.0: 0.29%
# 106.0: -1.97%
# 107.0: 10.67%
# 108.0: -17.96%
# 109.0: 18.96%
# None: -7.58%
# 南投縣
# 101.0: -7.53%
# 102.0: 6.86%
# 103.0: 1.91%
# 104.0: -11.48%
# 105.0: 6.02%
# 106.0: -1.84%
# 107.0: 0.75%
# 108.0: -14.30%
# 109.0: 19.42%
# None: -6.41%
# 彰化縣
# 101.0: -7.33%
# 102.0: 5.97%
# 103.0: -1.00%
# 104.0: -8.02%
# 105.0: 6.21%
# 106.0: -1.01%
# 107.0: 7.21%
# 108.0: -20.72%
# 109.0: 19.73%
# None: -5.26%
# 雲林縣
# 101.0: N/A
# 102.0: N/A
# 103.0: N/A
# 104.0: N/A
# 105.0: N/A
# 106.0: N/A
# 107.0: N/A
# 108.0: N/A
# 109.0: N/A
# None: N/A
# 嘉義市
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9252\3851125582.py in <module>
#      39 for i, city in enumerate(cities):
#      40     print(city)
# ---> 41     if len(growth_rates[i]) < len(years) - 1:
#      42         growth_rates[i] += [None] * (len(years) - 1 - len(growth_rates[i]))
#      43     for j, year in enumerate(years):
#
# IndexError: list index out of range

# %% [markdown]
# #### 第三題
#     問：100學年~109學年哪種性別的平均視力不良率較嚴重？

# %% [markdown]
# #### 第四題
#     問：全國的公私立學校學生哪種校別的視力不良率較低？

# %% [markdown]
# #### 第五題
#     問：哪些縣市的學生視力不良率呈現逐年攀升？其中以哪一個縣市最為明顯？

# %% [markdown]
# #### 第六題
#     問：哪些縣市的學生視力不良率呈現逐年攀升？其中以哪一個縣市最為明顯？

# %% [markdown]
# #### 第七題
#     問：哪些縣市的學生視力不良率呈現逐年攀升？其中以哪一個縣市最為明顯？

# %% [markdown]
# #### 第八題
#     問：哪些縣市的學生視力不良率呈現逐年攀升？其中以哪一個縣市最為明顯？
