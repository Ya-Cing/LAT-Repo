# %%
import pandas as pd
#load data into a DataFrame object:
df =  pd.read_csv('0304 test.csv',encoding = "Big5")

print(df)
# Out:
#     學年度別       大專院校       高級中學       職業學校       國民中學       國民小學        幼兒園
# 0    70年   53049.96   21616.75   28353.78   20027.09   12254.20          -
# 1    71年   55869.18   21656.14   43475.99   23168.90   14872.66          -
# 2    72年   65000.68   22053.02   43949.43   22638.55   14346.20          -
# 3    73年   60808.55   15243.66   39050.71   25361.06   14743.58          -
# 4    74年   65651.22   26571.33   40051.93   27695.85   16572.49          -
# 5    75年  155901.90   27951.36   73079.23   28979.22   16476.64          -
# 6    76年  134802.27   29217.68   59202.94   33613.08   21366.48          -
# 7    77年  118537.37   34858.81   48890.74   35517.77   22985.32          -
# 8    78年  118475.42   45829.51   62344.37   44340.98   26422.17          -
# 9    79年   89860.38   65096.11   78563.30   52442.72   35821.83          -
# 10   80年  157250.56   68831.46   78377.21   60725.78   39698.97          -
# ...

# %%
import pandas as pd
#load data into a DataFrame object:
df =  pd.read_csv('0304 test.csv',encoding = "Big5")

print(df)
# Out:
#     學年度別       大專院校       高級中學       職業學校       國民中學       國民小學        幼兒園
# 0    70年   53049.96   21616.75   28353.78   20027.09   12254.20          -
# 1    71年   55869.18   21656.14   43475.99   23168.90   14872.66          -
# 2    72年   65000.68   22053.02   43949.43   22638.55   14346.20          -
# 3    73年   60808.55   15243.66   39050.71   25361.06   14743.58          -
# 4    74年   65651.22   26571.33   40051.93   27695.85   16572.49          -
# 5    75年  155901.90   27951.36   73079.23   28979.22   16476.64          -
# 6    76年  134802.27   29217.68   59202.94   33613.08   21366.48          -
# 7    77年  118537.37   34858.81   48890.74   35517.77   22985.32          -
# 8    78年  118475.42   45829.51   62344.37   44340.98   26422.17          -
# 9    79年   89860.38   65096.11   78563.30   52442.72   35821.83          -
# 10   80年  157250.56   68831.46   78377.21   60725.78   39698.97          -
# ...

# %%
import pandas as pd

print(pd.options.display.max_rows)
# Out:
# 60

# %%
import pandas as pd

df = pd.read_csv('0304 test.csv',encoding = "Big5")

df.head()
# Out:
#   學年度別      大專院校      高級中學      職業學校      國民中學      國民小學 幼兒園
# 0  70年  53049.96  21616.75  28353.78  20027.09  12254.20   -
# 1  71年  55869.18  21656.14  43475.99  23168.90  14872.66   -
# 2  72年  65000.68  22053.02  43949.43  22638.55  14346.20   -
# 3  73年  60808.55  15243.66  39050.71  25361.06  14743.58   -
# 4  74年  65651.22  26571.33  40051.93  27695.85  16572.49   -

# %%
temp = df[['學年度別', '國民小學']]
temp
# Out:
#     學年度別       國民小學
# 0    70年   12254.20
# 1    71年   14872.66
# 2    72年   14346.20
# 3    73年   14743.58
# 4    74年   16572.49
# 5    75年   16476.64
# 6    76年   21366.48
# 7    77年   22985.32
# 8    78年   26422.17
# 9    79年   35821.83
# 10   80年   39698.97
# 11   81年   48621.09
# 12   82年   48462.60
# 13   83年   51869.02
# 14   84年   68533.42
# 15   85年   75284.19
# 16   86年   82192.99
# 17   87年   83906.20
# 18   88年   74877.73
# 19   89年   80602.14
# 20   90年   94168.19
# 21   91年  104359.83
# 22   92年  100066.35
# 23   93年  102955.84
# 24   94年  109495.80
# 25   95年  113158.47
# 26   96年  116646.16
# 27   97年  125590.13
# 28   98年  135681.02
# 29   99年  143879.68
# 30  100年  152426.15
# 31  101年  164988.78
# 32  102年  174236.47
# 33  103年  173009.18
# 34  104年  172581.86
# 35  105年  178453.12
# 36  106年  183476.03
# 37  107年  183585.81
# 38  108年  184035.16
# 39  109年  180734.08
# 40  110年  177096.89

# %%
Type = temp.groupby(['學年度別'])['國民小學'].sum().reset_index()
Type['year'] = 110
Type
# Out:
#     學年度別       國民小學  year
# 0   100年  152426.15   110
# 1   101年  164988.78   110
# 2   102年  174236.47   110
# 3   103年  173009.18   110
# 4   104年  172581.86   110
# 5   105年  178453.12   110
# 6   106年  183476.03   110
# 7   107年  183585.81   110
# 8   108年  184035.16   110
# 9   109年  180734.08   110
# 10  110年  177096.89   110
# 11   70年   12254.20   110
# 12   71年   14872.66   110
# 13   72年   14346.20   110
# 14   73年   14743.58   110
# 15   74年   16572.49   110
# 16   75年   16476.64   110
# 17   76年   21366.48   110
# 18   77年   22985.32   110
# 19   78年   26422.17   110
# 20   79年   35821.83   110
# 21   80年   39698.97   110
# 22   81年   48621.09   110
# 23   82年   48462.60   110
# 24   83年   51869.02   110
# 25   84年   68533.42   110
# 26   85年   75284.19   110
# 27   86年   82192.99   110
# 28   87年   83906.20   110
# 29   88年   74877.73   110
# 30   89年   80602.14   110
# 31   90年   94168.19   110
# 32   91年  104359.83   110
# 33   92年  100066.35   110
# ...
